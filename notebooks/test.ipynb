# %%
from openai import OpenAI

client = OpenAI(api_key="Ysk-proj-pdWu2UCWNBpEsDKW48dvWoBtexCkOOWKkJFobzfb5Fwot48zHQ6QR86aU9bJyARJLX8B2GJMnwT3BlbkFJoB0jBudVh_pXMV4VvdT-3rrkaD6bpGopdS1wHtaMIgiqmXqt9asewX9mO1VgHvuY1b0lE3QjEAY")

try:
    response = client.responses.create(
        model="gpt-5.3",
        input="Say hello and confirm the API is working."
    )
    print(response.output[0].content[0].text)
except Exception as e:
    print("Error:", str(e))
# Out:
# Error: Error code: 401 - {'error': {'message': 'Incorrect API key provided: Ysk-proj**********************************************************************************************************************************************************jEAY. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
